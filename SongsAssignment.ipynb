# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujjwalsahu001/Google-Colab-P/blob/main/SongsAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/content/songs.csv", encoding='latin1')

# %%
df
# Out:
#        Unnamed: 0     video_id channelTitle  \
# 0               0  F44TK5EHCRo     T-Series
# 1               1  adx8Rsjp-c0     T-Series
# 2               2  36nQLyrR7Sw     T-Series
# 3               3  TKbifi5AMQo     T-Series
# 4               4  NNA21SoGqss     T-Series
# ...           ...          ...          ...
# 19340       19340  aouxczBof58     T-Series
# 19341       19341  NPhY3g0WE8c     T-Series
# 19342       19342  ZVYTLHLpgAw     T-Series
# 19343       19343  hArZnPWxb4A     T-Series
# 19344       19344  7_4K0iDtOvs     T-Series
#
#                                                    title  \
# 0      RAFTA RAFTA (Lo-Fi Mix) | Dj Moody | KK | Jeet...
# 1      TUM HO MERA PYAR (Lo-Fi Mix) | Dj Moody | KK, ...
# 2      ISHQ HOTHON SE (Lo-Fi Mix) (Audio) | Dj Moody ...
# 3      HUMKO PYAR HUA (Lo-Fi Mix) (Audio) | Dj Moody ...
# 4      Har Har Mahadev (Lyrical Video): Sachet Tandon...
# ...                                                  ...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     video_id channelTitle  \
# 0           0  F44TK5EHCRo     T-Series
# 1           1  adx8Rsjp-c0     T-Series
# 2           2  36nQLyrR7Sw     T-Series
# 3           3  TKbifi5AMQo     T-Series
# 4           4  NNA21SoGqss     T-Series
#
#                                                title  \
# 0  RAFTA RAFTA (Lo-Fi Mix) | Dj Moody | KK | Jeet...
# 1  TUM HO MERA PYAR (Lo-Fi Mix) | Dj Moody | KK, ...
# 2  ISHQ HOTHON SE (Lo-Fi Mix) (Audio) | Dj Moody ...
# 3  HUMKO PYAR HUA (Lo-Fi Mix) (Audio) | Dj Moody ...
# 4  Har Har Mahadev (Lyrical Video): Sachet Tandon...
#
#                                          description  \
# 0  Presenting the song "RAFTA RAFTA (Lo-Fi Mix)" ...
# 1  Presenting the song "TUM HO MERA PYAR (Lo-Fi M...
# 2  Presenting the song "ISHQ HOTHON SE (Lo-Fi Mix...
# 3  Presenting the song "HUMKO PYAR HUA (Lo-Fi Mix...
# 4  T-Series Presents "Har Har Mahadev (Lyrical Vi...
#
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0     video_id channelTitle  \
# 19340       19340  aouxczBof58     T-Series
# 19341       19341  NPhY3g0WE8c     T-Series
# 19342       19342  ZVYTLHLpgAw     T-Series
# 19343       19343  hArZnPWxb4A     T-Series
# 19344       19344  7_4K0iDtOvs     T-Series
#
#                                                    title  \
# 19340  ROLA PE GAYA  FULL SONG| PATIALA HOUSE | AKSHA...
# 19341                  Patiala House-Official Trailer II
# 19342  Kyun Mein Jagoon Song (Patiala House ) | Aksha...
# 19343  Laung Da Lashkara (Patiala House) Full Song | ...
# 19344  "Patiala House" Official Trailer 2 | Akshay Kumar
#
#                                              description  \
# 19340  Watch the song "Rola Pe Gaya" from the movie '...
# 19341      Patiala house upcoming movie official trailer
# 19342  "Here's presenting the song ""Kyun Main Jagoon...
# 19343  Watch the full video song "Laung Da Lashkara" ...
# 19344  Here's presenting the official trailer from th...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19345 entries, 0 to 19344
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     19345 non-null  int64
#  1   video_id       19345 non-null  object
#  2   channelTitle   19345 non-null  object
#  3   title          19345 non-null  object
#  4   description    19342 non-null  object
#  5   tags           19345 non-null  object
#  6   publishedAt    19345 non-null  object
#  7   viewCount      19345 non-null  int64
#  8   likeCount      19345 non-null  int64
#  9   favoriteCount  19345 non-null  int64
#  10  commentCount   19345 non-null  int64
#  11  duration       19345 non-null  object
#  12  definition     19345 non-null  object
#  13  caption        19345 non-null  bool
# dtypes: bool(1), int64(5), object(8)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0     viewCount     likeCount  favoriteCount   commentCount
# count  19345.000000  1.934500e+04  1.934500e+04        19345.0   19345.000000
# mean    9672.000000  1.193826e+07  8.718149e+04            0.0    2636.024141
# std     5584.564814  5.484973e+07  3.610099e+05            0.0   12487.178242
# min        0.000000  0.000000e+00  0.000000e+00            0.0       0.000000
# 25%     4836.000000  8.044200e+04  6.440000e+02            0.0      37.000000
# 50%     9672.000000  3.627810e+05  3.929000e+03            0.0     184.000000
# 75%    14508.000000  2.613386e+06  2.580300e+04            0.0     961.000000
# max    19344.000000  1.536719e+09  1.284022e+07            0.0  420375.000000

# %%
df.shape
# Out:
# (19345, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'video_id', 'channelTitle', 'title', 'description',
#        'tags', 'publishedAt', 'viewCount', 'likeCount', 'favoriteCount',
#        'commentCount', 'duration', 'definition', 'caption'],
#       dtype='object')

# %%
columns = df[["title","viewCount","likeCount"]]
print(columns)
# Out:
#                                                    title  viewCount  likeCount
# 0      RAFTA RAFTA (Lo-Fi Mix) | Dj Moody | KK | Jeet...       7299        241
# 1      TUM HO MERA PYAR (Lo-Fi Mix) | Dj Moody | KK, ...       4212        144
# 2      ISHQ HOTHON SE (Lo-Fi Mix) (Audio) | Dj Moody ...       2849         79
# 3      HUMKO PYAR HUA (Lo-Fi Mix) (Audio) | Dj Moody ...       3991        116
# 4      Har Har Mahadev (Lyrical Video): Sachet Tandon...     101950       6230
# ...                                                  ...        ...        ...
# 19340  ROLA PE GAYA  FULL SONG| PATIALA HOUSE | AKSHA...     636734        943
# 19341                  Patiala House-Official Trailer II      86841       1084
# 19342  Kyun Mein Jagoon Song (Patiala House ) | Aksha...     364995       1865
# 19343  Laung Da Lashkara (Patiala House) Full Song | ...   13663672      67331
# 19344  "Patiala House" Official Trailer 2 | Akshay Kumar    1662209      29257
#
# ...

# %%
highest_views = df[df["viewCount"] > 15000000]
df = pd.DataFrame()
print(highest_views)
# Out:
#        Unnamed: 0     video_id channelTitle  \
# 39             39  VAdGW7QDJiU     T-Series
# 48             48  ZWUgBdzgGyQ     T-Series
# 95             95  AQEc4BwX6dk     T-Series
# 112           112  4-30eu39wRM     T-Series
# 239           239  jyZsX8OyrmQ     T-Series
# ...           ...          ...          ...
# 19295       19295  KWCLOpaZeLc     T-Series
# 19298       19298  -Hb2DeHvvEg     T-Series
# 19299       19299  jAUSF4_ygJg     T-Series
# 19305       19305  ZTmF2v59CtI     T-Series
# 19330       19330  fbdxYoFb64g     T-Series
#
#                                                    title  \
# 39     Jawan: Chaleya (Hindi) | Shah Rukh Khan | Naya...
# 48     YAARIYAN 2 (TEASER): Divya,Yash,Meezaan,Anaswa...
# 95     Jawan: Zinda Banda Song |Shah Rukh Khan |Atlee...
# 112    Guru Randhawa: You Talking To Me? (Official Mu...
# 239    Tumhe Kitna Pyaar Karte (Video) Bawaal | Varun...
# ...                                                  ...
# ...

# %%
df = pd.read_csv("/content/songs.csv", encoding='latin1')
filter_vandc = df[(df["viewCount"]>1500000) & (df["likeCount"] > 15000)]
print(filter_vandc)
# Out:
#        Unnamed: 0     video_id channelTitle  \
# 24             24  XRhWn0iCW9s     T-Series
# 34             34  qXB5Bcj7F6M     T-Series
# 39             39  VAdGW7QDJiU     T-Series
# 44             44  djXuC5EdvyA     T-Series
# 47             47  posAOLFBpaM     T-Series
# ...           ...          ...          ...
# 19330       19330  fbdxYoFb64g     T-Series
# 19332       19332  0mfen2YtSj8     T-Series
# 19334       19334  zqQhbs1q4-E     T-Series
# 19343       19343  hArZnPWxb4A     T-Series
# 19344       19344  7_4K0iDtOvs     T-Series
#
#                                                    title  \
# 24     MERE KANHA BHOOL NA JAANA (???? ?????? ??? ?? ...
# 34     Spirit Of Fighter | Hrithik Roshan | Deepika P...
# 39     Jawan: Chaleya (Hindi) | Shah Rukh Khan | Naya...
# 44     VANDE BHARATAM | Vishal Mishra, Arko | Manoj M...
# 47     BAARISH HAI JAANAM: Payal Dev, Stebin Ben, Har...
# ...                                                  ...
# ...

# %%
df.isnull()
# Out:
#        Unnamed: 0  video_id  channelTitle  title  description   tags  \
# 0           False     False         False  False        False  False
# 1           False     False         False  False        False  False
# 2           False     False         False  False        False  False
# 3           False     False         False  False        False  False
# 4           False     False         False  False        False  False
# ...           ...       ...           ...    ...          ...    ...
# 19340       False     False         False  False        False  False
# 19341       False     False         False  False        False  False
# 19342       False     False         False  False        False  False
# 19343       False     False         False  False        False  False
# 19344       False     False         False  False        False  False
#
#        publishedAt  viewCount  likeCount  favoriteCount  commentCount  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# video_id         0
# channelTitle     0
# title            0
# description      3
# tags             0
# publishedAt      0
# viewCount        0
# likeCount        0
# favoriteCount    0
# commentCount     0
# duration         0
# definition       0
# caption          0
# dtype: int64
